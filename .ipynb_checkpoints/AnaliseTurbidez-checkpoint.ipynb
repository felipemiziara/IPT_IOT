# %%
import pandas as pd

# %% [markdown]
# #Carregando os dados

# %%
df = pd.read_csv('/Users/felipemiziara/Downloads/turbidez_sabesp.csv', sep=';')

# %%
df.shape
# Out:
# (24990, 7)

# %%
df.columns
# Out:
# Index(['Timestamp', 'Voltage', 'Sensor', 'NTU', 'Consumo Humano',
#        'Consumo Animal', 'Consumo Plantas'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Timestamp           object
# Voltage            float64
# Sensor              object
# NTU                float64
# Consumo Humano      object
# Consumo Animal      object
# Consumo Plantas     object
# dtype: object

# %%
df.describe()
# Out:
#             Voltage           NTU
# count  24987.000000  24987.000000
# mean       3.098846     88.307798
# std        0.650720    336.926921
# min       -0.258750  -4346.441406
# 25%        3.035250      1.126359
# 50%        3.095000     61.401428
# 75%        3.307063     63.371155
# max        5.000000   2872.915039

# %%
df['Voltage'].describe()
# Out:
# count    24987.000000
# mean         3.098846
# std          0.650720
# min         -0.258750
# 25%          3.035250
# 50%          3.095000
# 75%          3.307063
# max          5.000000
# Name: Voltage, dtype: float64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
df.plot()
# Out:
# <Axes: >

# %%
df.plot(kind='density',subplots=True,layout=(4,2),figsize=(12,12),sharex=False)
plt.show()

# %%
df['Voltage'].plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
df['NTU'].plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
df['Voltage'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['NTU'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Voltage'].plot.box()
# Out:
# <Axes: >

# %%
df['NTU'].plot.box()
# Out:
# <Axes: >

# %%
df['Timestamp'] =  pd.to_datetime(df['Timestamp'])

# %%
df.dtypes
# Out:
# Timestamp           datetime64[ns]
# Voltage                    float64
# Sensor                      object
# NTU                        float64
# Consumo Humano              object
# Consumo Animal              object
# Consumo Plantas             object
# Intervalo          timedelta64[ns]
# dtype: object

# %%
print(df)
# Out:
#                 Timestamp   Voltage           Sensor       NTU Consumo Humano  \
# 0     2024-07-14 19:13:16  4.818071  Water Turbidity  3.638584      attention
# 1     2024-07-14 19:13:21  4.873016  Water Turbidity  2.539683      attention
# 2     2024-07-14 19:13:27  4.956044  Water Turbidity  0.879121          clean
# 3     2024-07-14 19:13:32  4.743590  Water Turbidity  5.128205          dirty
# 4     2024-07-14 19:13:37  4.747253  Water Turbidity  5.054945          dirty
# ...                   ...       ...              ...       ...            ...
# 24985 2024-08-11 17:54:30  3.510125  Water Turbidity  1.057763      attention
# 24986 2024-08-11 17:54:35  3.510125  Water Turbidity  1.057763      attention
# 24987 2024-08-11 17:54:40  3.509875  Water Turbidity  1.058436      attention
# 24988 2024-08-11 17:54:44  3.509875  Water Turbidity  1.058436      attention
# 24989 2024-08-11 17:54:49  3.509625  Water Turbidity  1.059108      attention
#
#       Consumo Animal Consumo Plantas
# 0              clean           clean
# 1              clean           clean
# 2              clean           clean
# 3          attention           clean
# 4          attention           clean
# ...              ...             ...
# 24985          clean           clean
# 24986          clean           clean
# 24987          clean           clean
# 24988          clean           clean
# 24989          clean           clean
#
# [24990 rows x 7 columns]

# %%
print(df)
# Out:
#                 Timestamp   Voltage           Sensor       NTU Consumo Humano  \
# 0     2024-07-14 19:13:16  4.818071  Water Turbidity  3.638584      attention
# 1     2024-07-14 19:13:21  4.873016  Water Turbidity  2.539683      attention
# 2     2024-07-14 19:13:27  4.956044  Water Turbidity  0.879121          clean
# 3     2024-07-14 19:13:32  4.743590  Water Turbidity  5.128205          dirty
# 4     2024-07-14 19:13:37  4.747253  Water Turbidity  5.054945          dirty
# ...                   ...       ...              ...       ...            ...
# 24985 2024-08-11 17:54:30  3.510125  Water Turbidity  1.057763      attention
# 24986 2024-08-11 17:54:35  3.510125  Water Turbidity  1.057763      attention
# 24987 2024-08-11 17:54:40  3.509875  Water Turbidity  1.058436      attention
# 24988 2024-08-11 17:54:44  3.509875  Water Turbidity  1.058436      attention
# 24989 2024-08-11 17:54:49  3.509625  Water Turbidity  1.059108      attention
#
#       Consumo Animal Consumo Plantas       Intervalo
# 0              clean           clean             NaT
# 1              clean           clean 0 days 00:00:05
# 2              clean           clean 0 days 00:00:06
# 3          attention           clean 0 days 00:00:05
# 4          attention           clean 0 days 00:00:05
# ...              ...             ...             ...
# 24985          clean           clean 0 days 00:00:05
# 24986          clean           clean 0 days 00:00:05
# 24987          clean           clean 0 days 00:00:05
# 24988          clean           clean 0 days 00:00:04
# 24989          clean           clean 0 days 00:00:05
#
# [24990 rows x 8 columns]

# %% [markdown]
# # Limpando registros com hora nula

# %%
if df['Timestamp'].isnull().any():
    df.dropna(subset=['Timestamp'], inplace=True)

# %%
df['Grupos'] = df['Timestamp'].dt.floor('6min')
df.head()
# Out:
#             Timestamp   Voltage           Sensor       NTU Consumo Humano  \
# 0 2024-07-14 19:13:16  4.818071  Water Turbidity  3.638584      attention
# 1 2024-07-14 19:13:21  4.873016  Water Turbidity  2.539683      attention
# 2 2024-07-14 19:13:27  4.956044  Water Turbidity  0.879121          clean
# 3 2024-07-14 19:13:32  4.743590  Water Turbidity  5.128205          dirty
# 4 2024-07-14 19:13:37  4.747253  Water Turbidity  5.054945          dirty
#
#   Consumo Animal Consumo Plantas       Intervalo              Grupos
# 0          clean           clean             NaT 2024-07-14 19:12:00
# 1          clean           clean 0 days 00:00:05 2024-07-14 19:12:00
# 2          clean           clean 0 days 00:00:06 2024-07-14 19:12:00
# 3      attention           clean 0 days 00:00:05 2024-07-14 19:12:00
# 4      attention           clean 0 days 00:00:05 2024-07-14 19:12:00

# %%
df_agrupado = df.groupby('Grupos')

max_min_values = df_agrupado['Voltage'].agg(['max', 'min'])

print(max_min_values)
# Out:
#                           max       min
# Grupos
# 2024-07-14 19:12:00  5.000000  4.272283
# 2024-07-14 19:18:00  4.993895  4.708180
# 2024-07-14 19:54:00  5.000000  1.131868
# 2024-07-14 20:00:00  5.000000  2.787546
# 2024-07-15 18:54:00  5.000000  5.000000
# ...                       ...       ...
# 2024-08-11 15:42:00  3.493125  3.460500
# 2024-08-11 16:42:00  3.500875  3.468875
# 2024-08-11 16:48:00  3.501125  3.480000
# 2024-08-11 17:48:00  3.510625  3.477375
# 2024-08-11 17:54:00  3.510250  3.509500
#
# [432 rows x 2 columns]

# %%
def remove_outliers_iqr(group):
    Q1 = group['Voltage'].quantile(0.15)
    Q3 = group['Voltage'].quantile(0.90)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return group[((group['Voltage'] >= lower_bound) & (group['Voltage'] <= upper_bound))]

# Aplique a função aos seus dados agrupados
filtered_data = df_agrupado.apply(remove_outliers_iqr, include_groups=False)

# Visualize os resultados
filtered_data.head()

#print(filtered_data)
# Out:
#                                 Timestamp   Voltage           Sensor  \
# Grupos
# 2024-07-14 19:12:00 0 2024-07-14 19:13:16  4.818071  Water Turbidity
#                     1 2024-07-14 19:13:21  4.873016  Water Turbidity
#                     2 2024-07-14 19:13:27  4.956044  Water Turbidity
#                     3 2024-07-14 19:13:32  4.743590  Water Turbidity
#                     4 2024-07-14 19:13:37  4.747253  Water Turbidity
#
#                             NTU Consumo Humano Consumo Animal Consumo Plantas  \
# Grupos
# 2024-07-14 19:12:00 0  3.638584      attention          clean           clean
#                     1  2.539683      attention          clean           clean
#                     2  0.879121          clean          clean           clean
#                     3  5.128205          dirty      attention           clean
#                     4  5.054945          dirty      attention           clean
#
#                             Intervalo
# Grupos
# 2024-07-14 19:12:00 0             NaT
#                     1 0 days 00:00:05
#                     2 0 days 00:00:06
#                     3 0 days 00:00:05
#                     4 0 days 00:00:05

# %%
df_agrupado2 = filtered_data.groupby('Grupos')

max_min_values = df_agrupado2['Voltage'].agg(['max', 'min'])

print(max_min_values)
# Out:
#                           max       min
# Grupos
# 2024-07-14 19:12:00  5.000000  4.272283
# 2024-07-14 19:18:00  4.993895  4.708180
# 2024-07-14 19:54:00  5.000000  3.990232
# 2024-07-14 20:00:00  5.000000  4.555555
# 2024-07-15 18:54:00  5.000000  5.000000
# ...                       ...       ...
# 2024-08-11 15:42:00  3.493125  3.491750
# 2024-08-11 16:42:00  3.500875  3.500000
# 2024-08-11 16:48:00  3.501125  3.500000
# 2024-08-11 17:48:00  3.510625  3.508625
# 2024-08-11 17:54:00  3.510250  3.509500
#
# [432 rows x 2 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Supondo que você queira os dados do dia '2023-08-11'
data_especifica = '2024-07-14'
dados_do_dia = df[df['Timestamp'].dt.date == pd.to_datetime(data_especifica).date()]

filtrados = filtered_data[filtered_data['Timestamp'].dt.date == pd.to_datetime(data_especifica).date()]

# Supondo que você já tenha o DataFrame 'df' com os dados originais
# e o DataFrame 'filtered_data' com os dados após a tentativa de remoção de outliers

# Visualizar a distribuição da coluna 'voltage' antes e depois da filtragem
sns.boxplot(x='Grupos', y='Voltage', data=dados_do_dia)  # Antes da filtragem
plt.show()

sns.boxplot(x='Grupos', y='Voltage', data=filtrados)  # Depois da filtragem
plt.show()

# %%
dados_do_dia['Voltage'].plot.hist(label='Dados originais')
filtrados['Voltage'].plot.hist(label='Após remoção de discrepâncias')

plt.legend()

# %%
filtered_data['Voltage'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
filtered_data['Voltage'].plot.box()
# Out:
# <Axes: >

# %%
df['Voltage'].plot.box()
# Out:
# <Axes: >

# %%
avgVolts = filtered_data.groupby('Grupos')['Voltage'].agg(['mean', 'std', 'min', 'max'])

avgVolts.head()

avgVolts.dtypes
#df = pd.DataFrame(avgVolts, index=filtered_data.index)


#filtered_data = filtered_data.cumsum()
#plt.figure();
#filtered_data.plot()
# Out:
# mean    float64
# std     float64
# min     float64
# max     float64
# dtype: object

# %%
avgVolts.plot(kind='line',subplots=True,layout=(4,2),figsize=(24,12),sharex=False)
plt.show()

# %%
data_especifica = '2024-08-09'
#avgVolts['Timestamp'] =  pd.to_datetime(avgVolts['Grupos'])


dadosVerdade = avgVolts[avgVolts.index.date >= pd.to_datetime(data_especifica).date()]

dadosVerdade.plot(kind='line',subplots=True,layout=(4,2),figsize=(24,12),sharex=False)
plt.show()
